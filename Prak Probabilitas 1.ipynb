# %%
import pandas as pd
df = pd.read_clipboard()
df
# Out:
#        Nama Gender  Angkatan   Tinggi Badan  Waktu Perjalanan Wilayah Tinggal
# 0      Diva      P      2020            170                15   Taman Anggrek
# 1     Manda      P      2020            165                60          Bekasi
# 2     Rukhy      P      2020            160                60          Bekasi
# 3       Tya      P      2020            150                45   Taman Anggrek
# 4       Ica      P      2020            165                60          Bekasi
# 5     Delia      P      2020            160                60          Jakbar
# 6      Gita      P      2020            160                60         Tangsel
# 7      Viky      L      2020            160                60          Bekasi
# 8       Upo      L      2020            150                60         Kalteng
# 9      Ibnu      L      2020            170                70         Tangsel
# 10    Ricky      L      2020            160                45          Grogol
# ...

# %%
df = pd.read_csv("your_file.csv", sep=';')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("your_file.csv", sep=';')
#       2 df
#
# File ~\anaconda3d\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd
df = pd.read_csv("C:/Users/NamaKamu/Documents/Praktikum Probabilitas.csv", sep=';')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("C:/Users/NamaKamu/Documents/Praktikum Probabilitas.csv", sep=';')
#       3 df
#
# ...

# %%
df = pd.read_csv("C:/Users/NamaKamu/Documents/Praktikum Probabilitas1.csv", sep=',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv("C:/Users/NamaKamu/Documents/Praktikum Probabilitas1.csv", sep=',')
#
# File ~\anaconda3d\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.read_csv("C:/Users/NamaKamu/Documents/Praktikum Probabilitas 1.csv", sep=',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv("C:/Users/NamaKamu/Documents/Praktikum Probabilitas 1.csv", sep=',')
#
# File ~\anaconda3d\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv("C:/Users/NamaKamu/Documents/Praktikum Probabilitas 2.csv", sep=';')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("C:/Users/NamaKamu/Documents/Praktikum Probabilitas 2.csv", sep=';')
#       3 df
#
# ...

# %%
import os
print(os.getcwd())  # Cek folder kerja Jupyter
# Out:
# C:\Users\Fatihul Nizar T

# %%
df = pd.read_csv("Praktikum Probabilitas 2.csv", sep=",")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_csv("Praktikum Probabilitas 2.csv", sep=",")
#       2 df
#
# File ~\anaconda3d\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df = pd.read_csv("Praktikum Probabilitas 2.csv", sep=",")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_csv("Praktikum Probabilitas 2.csv", sep=",")
#       2 df
#
# File ~\anaconda3d\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df = pd.read_csv("Praktikum Probabilitas.csv", sep=",")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_csv("Praktikum Probabilitas.csv", sep=",")
#       2 df
#
# File ~\anaconda3d\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df = pd.read_csv("Praktikum Prob.csv", sep=",")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv("Praktikum Prob.csv", sep=",")
#       2 df
#
# File ~\anaconda3d\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df = pd.read_csv("Praktikum Prob 1.csv", sep=",")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_csv("Praktikum Prob 1.csv", sep=",")
#       2 df
#
# File ~\anaconda3d\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import os
print(os.getcwd())  # Menampilkan folder kerja saat ini
# Out:
# C:\Users\Fatihul Nizar T

# %%
import pandas as pd

df = pd.read_csv("Praktikum Prob 2.csv", sep=";")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("Praktikum Prob 2.csv", sep=";")
#       4 df
#
# File ~\anaconda3d\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
print(os.getcwd())  # Menampilkan folder tempat Jupyter mencari file
# Out:
# C:\Users\Fatihul Nizar T

# %%
df = pd.read_csv(r"C:\Users\Fatihul Nizar T\Downloads\Praktikum Prob 2.csv", sep=";")
df
# Out:
#        Nama Gender  Angkatan   Tinggi Badan  Waktu Perjalanan Wilayah Tinggal
# 0      Diva      P      2020            170                15   Taman Anggrek
# 1     Manda      P      2020            165                60          Bekasi
# 2     Rukhy      P      2020            160                60          Bekasi
# 3       Tya      P      2020            150                45   Taman Anggrek
# 4       Ica      P      2020            165                60          Bekasi
# 5     Delia      P      2020            160                60          Jakbar
# 6      Gita      P      2020            160                60         Tangsel
# 7      Viky      L      2020            160                60          Bekasi
# 8       Upo      L      2020            150                60         Kalteng
# 9      Ibnu      L      2020            170                70         Tangsel
# 10    Ricky      L      2020            160                45          Grogol
# ...

# %%
df_xlsx = pd.read_excel("Praktikum Prob 2.xlsx")
df_xlsx.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df_xlsx = pd.read_excel("Praktikum Prob 2.xlsx")
#       2 df_xlsx.head()
#
# File ~\anaconda3d\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
# ...

# %%
df = pd.read_csv(r"C:\Users\Fatihul Nizar T\Downloads\Praktikum Prob 2.xlsx", sep=";")
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\Fatihul Nizar T\Downloads\Praktikum Prob 2.xlsx", sep=";")
#       2 df
#
# File ~\anaconda3d\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

df_xlsx = pd.read_excel(r"C:\Users\Fatihul Nizar T\Downloads\Praktikum Prob 2.xlsx")
df_xlsx.head()
# Out:
#     Nama Gender  Angkatan   Tinggi Badan  Waktu Perjalanan Wilayah Tinggal
# 0   Diva      P      2020            170                15   Taman Anggrek
# 1  Manda      P      2020            165                60          Bekasi
# 2  Rukhy      P      2020            160                60          Bekasi
# 3    Tya      P      2020            150                45   Taman Anggrek
# 4    Ica      P      2020            165                60          Bekasi

# %%
print(df_xlsx)
# Out:
#        Nama Gender  Angkatan   Tinggi Badan  Waktu Perjalanan Wilayah Tinggal
# 0      Diva      P      2020            170                15   Taman Anggrek
# 1     Manda      P      2020            165                60          Bekasi
# 2     Rukhy      P      2020            160                60          Bekasi
# 3       Tya      P      2020            150                45   Taman Anggrek
# 4       Ica      P      2020            165                60          Bekasi
# 5     Delia      P      2020            160                60          Jakbar
# 6      Gita      P      2020            160                60         Tangsel
# 7      Viky      L      2020            160                60          Bekasi
# 8       Upo      L      2020            150                60         Kalteng
# 9      Ibnu      L      2020            170                70         Tangsel
# 10    Ricky      L      2020            160                45          Grogol
# ...

# %%
import pandas as pd

df_xlsx = pd.read_excel(r"C:\Users\Fatihul Nizar T\Downloads\Praktikum Prob 2.xlsx")

# %%
import pandas as pd

df_xlsx = pd.read_excel(r"C:\Users\Fatihul Nizar T\Downloads\Praktikum Prob 2.xlsx")

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
import pandas as pd

data_nama = pd.read_csv("C:/SMT Antara/PrakStatistika/BahanPraktikum1_Statistika.csv", sep=",")  
data_nama
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 3
#       1 import pandas as pd
# ----> 3 data_nama = pd.read_csv("C:/SMT Antara/PrakStatistika/BahanPraktikum1_Statistika.csv", sep=",")
#       4 data_nama
#
# ...

# %%
data_nama = pd.read_csv(r"C:\Users\Fatihul Nizar T\Downloads\Praktikum Prob 2.csv", sep=",")
data_nama
# Out:
#    Nama;Gender;Angkatan; Tinggi Badan;Waktu Perjalanan;Wilayah Tinggal
# 0                    Diva;P;2020;170;15;Taman Anggrek
# 1                          Manda;P;2020;165;60;Bekasi
# 2                          Rukhy;P;2020;160;60;Bekasi
# 3                     Tya;P;2020;150;45;Taman Anggrek
# 4                            Ica;P;2020;165;60;Bekasi
# 5                          Delia;P;2020;160;60;Jakbar
# 6                          Gita;P;2020;160;60;Tangsel
# 7                           Viky;L;2020;160;60;Bekasi
# 8                           Upo;L;2020;150;60;Kalteng
# 9                          Ibnu;L;2020;170;70;Tangsel
# 10                         Ricky;L;2020;160;45;Grogol
# 11                      Akmal;L;2020;160;35;Tangerang
# 12                      Dhila;P;2020;155;60;Tangerang
# 13                          Noto;L;2020;170;45;Grogol
# 14                         Ricardo;L;2020;170;30;Jawa
# 15                          Alya;P;2020;170;60;Brunai
# ...
