# %%
import pandas as pd

# Load dataset
file_path = "C:/dataset/dataset_fatihul2.csv"  # Sesuaikan dengan path file Anda
df = pd.read_csv(file_path, delimiter=";")

# Menghapus spasi di nama kolom
df.columns = df.columns.str.strip()

# 2. Subset Data: Menggunakan kolom "Tinggi Badan"
df_subset = df[["Tinggi Badan"]]
print("Subset Data:\n", df_subset.head())

# 3. Mengubah nilai pada kolom "Tinggi Badan"
df["Kategori Tinggi"] = df["Tinggi Badan"].apply(lambda x: "Tinggi" if x > 160 else "Pendek")
print("\nSetelah Mengubah Nilai Tinggi Badan:\n", df[["Tinggi Badan", "Kategori Tinggi"]].head())

# 4. Menambah Variabel
# Menambah kolom "Jurusan" dan "Fakultas"
df["Jurusan"] = "Infor20"
df["Fakultas"] = "FTI"
print("\nSetelah Menambah Kolom:\n", df.head())

# 5. Delete Variabel: Hapus kolom "Fakultas"
df.drop(columns=["Fakultas"], inplace=True)
print("\nSetelah Menghapus Kolom Fakultas:\n", df.head())

# 6. Merge Data Frame
# Gabung Nama dan Gender
df["Nama_Gender"] = df["Nama"] + "_" + df["Gender"]
# Gabung Angkatan dan Tinggi Badan
df["Angkatan_Tinggi"] = df["Angkatan"].astype(str) + "_" + df["Tinggi Badan"].astype(str)
# Gabung dua kolom gabungan di atas
df["Gabungan"] = df["Nama_Gender"] + "_" + df["Angkatan_Tinggi"]
print("\nSetelah Merge Data Frame:\n", df[["Nama_Gender", "Angkatan_Tinggi", "Gabungan"]].head())

# 7. Merge Baris
# Gabungkan baris 1-5 dan 25-30, lalu gabungkan hasilnya
df_baris1 = df.iloc[0:5]
df_baris2 = df.iloc[24:30]
df_baris_merged = pd.concat([df_baris1, df_baris2])
print("\nGabungan Baris:\n", df_baris_merged)

# 8. Sort Data Frame berdasarkan "Waktu Perjalanan"
df_sorted = df.sort_values(by="Waktu Perjalanan")
print("\nSetelah Sorting Data:\n", df_sorted.head())

# Simpan hasil ke file baru
output_path = "Hasil_Transformasi.csv"
df.to_csv(output_path, index=False)
print("\nData telah disimpan ke", output_path)
# Out:
# Subset Data:
#     Tinggi Badan
# 0           170
# 1           165
# 2           160
# 3           150
# 4           165
#
# Setelah Mengubah Nilai Tinggi Badan:
#     Tinggi Badan Kategori Tinggi
# 0           170          Tinggi
# 1           165          Tinggi
# 2           160          Pendek
# 3           150          Pendek
# 4           165          Tinggi
#
# Setelah Menambah Kolom:
#      Nama Gender  Angkatan  Tinggi Badan  Waktu Perjalanan Wilayah Tinggal  \
# 0   Diva      P      2020           170                15   Taman Anggrek
# 1  Manda      P      2020           165                60          Bekasi
# 2  Rukhy      P      2020           160                60          Bekasi
# 3    Tya      P      2020           150                45   Taman Anggrek
# 4    Ica      P      2020           165                60          Bekasi
#
#   Kategori Tinggi  Jurusan Fakultas
# 0          Tinggi  Infor20      FTI
# 1          Tinggi  Infor20      FTI
# ...

# %%
import pandas as pd

# Load dataset
file_path = "C:/dataset/dataset_fatihul2.csv"  # Sesuaikan dengan path file Anda
df = pd.read_csv(file_path, delimiter=";")

# Menghapus spasi di nama kolom
df.columns = df.columns.str.strip()

# Subset Data: Menggunakan kolom "Tinggi Badan"
df_subset = df[["Tinggi Badan"]]
print("Subset Data:\n", df_subset.head())

# Simpan hasil subset ke file baru (opsional)
df_subset.to_csv("Subset_Tinggi_Badan.csv", index=False)
print("\nSubset data telah disimpan ke Subset_Tinggi_Badan.csv")
# Out:
# Subset Data:
#     Tinggi Badan
# 0           170
# 1           165
# 2           160
# 3           150
# 4           165
#
# Subset data telah disimpan ke Subset_Tinggi_Badan.csv

# %%
import pandas as pd

# Load dataset
file_path = "C:/dataset/dataset_fatihul2.csv"  # Sesuaikan dengan path file Anda
df = pd.read_csv(file_path, delimiter=";")

# Menghapus spasi di nama kolom
df.columns = df.columns.str.strip()

# Mengubah nilai pada kolom "Tinggi Badan"
df["Kategori Tinggi"] = df["Tinggi Badan"].apply(lambda x: "Tinggi" if x > 160 else "Pendek")

# Menampilkan hasil perubahan
print("\nSetelah Mengubah Nilai Tinggi Badan:\n", df[["Tinggi Badan", "Kategori Tinggi"]].head())

# Simpan hasil ke file baru
output_path = "Hasil_Transformasi.csv"
df.to_csv(output_path, index=False)
print("\nData telah disimpan ke", output_path)
# Out:
# Setelah Mengubah Nilai Tinggi Badan:
#     Tinggi Badan Kategori Tinggi
# 0           170          Tinggi
# 1           165          Tinggi
# 2           160          Pendek
# 3           150          Pendek
# 4           165          Tinggi
#
# Data telah disimpan ke Hasil_Transformasi.csv

# %%
import pandas as pd

# Load dataset
file_path = "C:/dataset/dataset_fatihul2.csv"  # Sesuaikan dengan path file Anda
df = pd.read_csv(file_path, delimiter=";")

# Menghapus spasi di nama kolom
df.columns = df.columns.str.strip()

# Menambah kolom "Jurusan" dan "Fakultas"
df["Jurusan"] = "Infor20"
df["Fakultas"] = "FTI"

# Menampilkan hasil perubahan
print("\nSetelah Menambah Kolom:\n", df.head())

# Simpan hasil ke file baru
output_path = "Hasil_Transformasi.csv"
df.to_csv(output_path, index=False)
print("\nData telah disimpan ke", output_path)
# Out:
# Setelah Menambah Kolom:
#      Nama Gender  Angkatan  Tinggi Badan  Waktu Perjalanan Wilayah Tinggal  \
# 0   Diva      P      2020           170                15   Taman Anggrek
# 1  Manda      P      2020           165                60          Bekasi
# 2  Rukhy      P      2020           160                60          Bekasi
# 3    Tya      P      2020           150                45   Taman Anggrek
# 4    Ica      P      2020           165                60          Bekasi
#
#    Jurusan Fakultas
# 0  Infor20      FTI
# 1  Infor20      FTI
# 2  Infor20      FTI
# 3  Infor20      FTI
# 4  Infor20      FTI
#
# Data telah disimpan ke Hasil_Transformasi.csv

# %%
import pandas as pd

# Load dataset
file_path = "C:/dataset/dataset_fatihul2.csv"  # Sesuaikan dengan path file Anda
df = pd.read_csv(file_path, delimiter=";")

# Menghapus spasi di nama kolom
df.columns = df.columns.str.strip()

# Menambah kolom "Jurusan" dan "Fakultas" (jika belum ada)
df["Jurusan"] = "Infor20"
df["Fakultas"] = "FTI"

# Menghapus kolom "Fakultas"
df.drop(columns=["Fakultas"], inplace=True)

# Menampilkan hasil setelah menghapus kolom
print("\nSetelah Menghapus Kolom Fakultas:\n", df.head())

# Simpan hasil ke file baru
output_path = "Hasil_Transformasi.csv"
df.to_csv(output_path, index=False)
print("\nData telah disimpan ke", output_path)
# Out:
# Setelah Menghapus Kolom Fakultas:
#      Nama Gender  Angkatan  Tinggi Badan  Waktu Perjalanan Wilayah Tinggal  \
# 0   Diva      P      2020           170                15   Taman Anggrek
# 1  Manda      P      2020           165                60          Bekasi
# 2  Rukhy      P      2020           160                60          Bekasi
# 3    Tya      P      2020           150                45   Taman Anggrek
# 4    Ica      P      2020           165                60          Bekasi
#
#    Jurusan
# 0  Infor20
# 1  Infor20
# 2  Infor20
# 3  Infor20
# 4  Infor20
#
# Data telah disimpan ke Hasil_Transformasi.csv

# %%
import pandas as pd

# Load dataset
file_path = "C:/dataset/dataset_fatihul2.csv"  # Sesuaikan dengan path file Anda
df = pd.read_csv(file_path, delimiter=";")

# Menghapus spasi di nama kolom
df.columns = df.columns.str.strip()

# Gabung Nama dan Gender
df["Nama_Gender"] = df["Nama"] + "_" + df["Gender"]

# Gabung Angkatan dan Tinggi Badan
df["Angkatan_Tinggi"] = df["Angkatan"].astype(str) + "_" + df["Tinggi Badan"].astype(str)

# Gabung dua kolom gabungan di atas
df["Gabungan"] = df["Nama_Gender"] + "_" + df["Angkatan_Tinggi"]

# Menampilkan hasil setelah merge
print("\nSetelah Merge Data Frame:\n", df[["Nama_Gender", "Angkatan_Tinggi", "Gabungan"]].head())

# Simpan hasil ke file baru
output_path = "Hasil_Merge.csv"
df.to_csv(output_path, index=False)
print("\nData telah disimpan ke", output_path)
# Out:
# Setelah Merge Data Frame:
#    Nama_Gender Angkatan_Tinggi          Gabungan
# 0      Diva_P        2020_170   Diva_P_2020_170
# 1     Manda_P        2020_165  Manda_P_2020_165
# 2     Rukhy_P        2020_160  Rukhy_P_2020_160
# 3       Tya_P        2020_150    Tya_P_2020_150
# 4       Ica_P        2020_165    Ica_P_2020_165
#
# Data telah disimpan ke Hasil_Merge.csv

# %%
import pandas as pd

# Load dataset
file_path = "C:/dataset/dataset_fatihul2.csv"  # Sesuaikan dengan path file Anda
df = pd.read_csv(file_path, delimiter=";")

# Menghapus spasi di nama kolom
df.columns = df.columns.str.strip()

# Gabungkan baris 1-5
df_baris1 = df.iloc[0:5]

# Gabungkan baris 25-30
df_baris2 = df.iloc[24:30]

# Gabungkan dua bagian di atas
df_baris_merged = pd.concat([df_baris1, df_baris2])

# Menampilkan hasil gabungan baris
print("\nGabungan Baris:\n", df_baris_merged)

# Simpan hasil ke file baru
output_path = "Hasil_Merge_Baris.csv"
df_baris_merged.to_csv(output_path, index=False)
print("\nData telah disimpan ke", output_path)
# Out:
# Gabungan Baris:
#         Nama Gender  Angkatan  Tinggi Badan  Waktu Perjalanan Wilayah Tinggal
# 0      Diva      P      2020           170                15   Taman Anggrek
# 1     Manda      P      2020           165                60          Bekasi
# 2     Rukhy      P      2020           160                60          Bekasi
# 3       Tya      P      2020           150                45   Taman Anggrek
# 4       Ica      P      2020           165                60          Bekasi
# 24     Reza      P      2024           156                55          Bekasi
# 25     Ismu      L      2024           167                65          Jaksel
# 26   Fauzan      L      2024           159                40          Grogol
# 27  Fatihul      L      2024           162                15          Jakbar
# 28     Dini      P      2024           165                20          Jakbar
#
# Data telah disimpan ke Hasil_Merge_Baris.csv

# %%
import pandas as pd

# Load dataset
file_path = "C:/dataset/dataset_fatihul2.csv"  # Sesuaikan dengan path file Anda
df = pd.read_csv(file_path, delimiter=";")

# Menghapus spasi di nama kolom
df.columns = df.columns.str.strip()

# Sorting berdasarkan "Waktu Perjalanan"
df_sorted = df.sort_values(by="Waktu Perjalanan")

# Menampilkan hasil sorting
print("\nSetelah Sorting Data berdasarkan Waktu Perjalanan:\n", df_sorted.head())

# Simpan hasil ke file baru
output_path = "Hasil_Sorting.csv"
df_sorted.to_csv(output_path, index=False)
print("\nData telah disimpan ke", output_path)
# Out:
# Setelah Sorting Data berdasarkan Waktu Perjalanan:
#         Nama Gender  Angkatan  Tinggi Badan  Waktu Perjalanan Wilayah Tinggal
# 0      Diva      P      2020           170                15   Taman Anggrek
# 27  Fatihul      L      2024           162                15          Jakbar
# 20   Rafael      L      2024           167                15          Jakbar
# 17    Riska      P      2020           160                15          Grogol
# 28     Dini      P      2024           165                20          Jakbar
#
# Data telah disimpan ke Hasil_Sorting.csv
